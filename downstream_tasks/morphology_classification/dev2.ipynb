# %%
from cross_match_utils import get_paired_classifications

classifications = get_paired_classifications('north', 'gz5', save_file=False)
# Out:
# Sky type is north, survey type is gz5
#
# Generating catalogs
# 100%|██████████| 10/10 [00:01<00:00,  9.20it/s]
# Matching coordinates
# Total number of matches: 4370
#
# Adding images to catalog
# 100%|██████████| 10/10 [00:00<00:00, 13.21it/s]

# %%
from astroclip.astroclip.clip_alignment import
# Out:
# <Table length=4370>
#       iauname       ...                      image
#        str19        ...                float64[3,152,152]
# ------------------- ... ------------------------------------------------
# J023210.94-000921.9 ...  -0.0030159992165863514 .. -0.006919929292052984
# J103041.40+320141.7 ...    -0.002038756385445595 .. -0.03965914249420166
# J110651.49+324103.2 ... -0.00039137282874435186 .. 0.0005575339891947806
# J152110.52+321922.3 ...   0.0009321430115960538 .. -0.011240208521485329
# J144619.57+322700.2 ...    0.0006383221480064094 .. 0.013917366042733192
# J150848.74+325148.8 ...  0.0018056314438581467 .. -0.0011884206905961037
# J022752.52-011103.6 ...     0.0030191405676305294 .. 0.01960371993482113
# J104954.05+321035.8 ...    0.013825152069330215 .. -0.012721571139991283
# J093816.94+320908.2 ...  -0.0005348413251340389 .. -0.012515855021774769
# J024531.93+005124.8 ...  -0.0007262876024469733 .. 0.0009842365980148315
# ...
